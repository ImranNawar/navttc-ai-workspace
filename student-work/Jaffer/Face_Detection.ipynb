# %%
import cv2
import matplotlib.pyplot as plt

# %%
def imshow(image, title=None, size=5):
    imgType =image.shape
    plt.figure(figsize=(size, size))
    if len(imgType) > 2:
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB), 'gray')
    else:
        plt.imshow(image, 'gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
image=cv2.imread("FacePics/images.jpg")
imshow(image, 'Original Image')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cascade = cv2.CascadeClassifier("haarcascade/haarcascade_frontalface_default.xml")
face = cascade.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=4, minSize=(30, 30))
for (x, y, w, h) in face:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
imshow(image, 'Detected Face')

# %%
image=cv2.imread("FacePics/images.jpg")
imshow(image, 'Original Image')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cascade = cv2.CascadeClassifier("haarcascade/haarcascade_eye.xml")
face = cascade.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=2)
for (x, y, w, h) in face:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
imshow(image, 'Detected Face')

# %%
image=cv2.imread("FacePics/Khan.jpg")
imshow(image, 'Original Image')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cascade = cv2.CascadeClassifier("haarcascade/haarcascade_frontalface_default.xml")
face = cascade.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5, minSize=(30, 30))
for (x, y, w, h) in face:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
imshow(image, 'Detected Face')
