# %% [markdown]
# ### 1. **Working with Variables and Data Types**
#
# 1. Create variables to store the following information:
#    - Your name
#    - Your age
#    - Your height
# 2. Print each of these variables.

# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
height=float(input("Enter your height: "))
print("Name: ",name,"\nAge: ",age,"\nHeight: ",height)
# Out:
# Enter your name: shakeel
# Enter your age: 26
# Enter your height: 5.5
# Name:  shakeel
# Age:  26
# Height:  5.5

# %% [markdown]
# ## 2. **Basic Arithmetic Operations**
# ### **Task**:
#
# 1. Perform basic arithmetic operations:
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#
#    on two numbers of your choice.

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
print("Addition: ",a+b,"\nSubtraction: ",a-b,"\nMultiplication: ",a*b,"\nDivision: ",a/b)
# Out:
# Enter first number: 34
# Enter second number: 35
# Addition:  69
# Subtraction:  -1
# Multiplication:  1190
# Division:  0.9714285714285714

# %% [markdown]
# ### 3. Conditional Statments
# 1. Create two variables: `is_sunny = True` and `is_raining = False`.
# 2. Use the `and` and `or` logical operators to check if it's both sunny and raining, or if it's either sunny or raining.
# 3. Use an `if` statement to print `"It's sunny!"` if `is_sunny` is `True`.

# %%
is_sunny=True
is_raining=False
if is_sunny and is_raining:
  print("It's both sunny and raining")
elif is_sunny or is_raining:
  print("It's either sunny or raining")
# Out:
# It's either sunny or raining

# %% [markdown]
# ### 4. Write Python Program to convert temperature in celcius to fahrenheit
# * F = (9/5) * C +32

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (9/5) * celsius + 32
print(f"{celsius} degrees Celsius is equal to {fahrenheit} degrees Fahrenheit")
# Out:
# Enter temperature in Celsius: 21
# 21.0 degrees Celsius is equal to 69.80000000000001 degrees Fahrenheit

# %% [markdown]
# ### 5. Write Python Program to find the area fo triangle

# %%
x=int(input("Enter the first side of triangle: "))
y=int(input("Enter the second side of triangle: "))
#z=input("Enter the third side of triangle: ")
triange=(x*y)/2
print("The perimeter of triangle is: ",triange)
# Out:
# Enter the first side of triangle: 23
# Enter the second side of triangle: 45
# The perimeter of triangle is:  517.5

# %% [markdown]
# ### 6. Discount Eligibility Checker
# Write a Python program that determines a customer's discount eligibility based on age and student status.
#
# Steps:
# - Create variables for age and student status
# - Use nested if statements to check:
#     1. If customer is senior citizen (age >= 60)
#     2. If customer is a student
#
#
# - Display appropriate discount message:
#     1. Senior students get 30% discount
#     2. Senior non-students get 20% discount
#     3. Non-senior students get 10% discount
#     4. Others get no discount

# %%
age = int(input("Enter customer's age: "))
is_student = input("Is the customer a student? (yes/no): ").lower() == "yes"

if age >= 60:
  if is_student:
    print("Senior student discount: 30%")
  else:
    print("Senior citizen discount: 20%")
else:
  if is_student:
    print("Student discount: 10%")
  else:
    print("No discount applicable.")
# Out:
# Enter customer's age: 23
# Is the customer a student? (yes/no): yes
# Student discount: 10%

# %% [markdown]
# ## 7. Print the multiplication table of a number (e.g., 5) up to 10.

# %%
t=int(input("Enter the number: "))
for i in range(1,11):
  print(t,"*",i,"=",t*i)
# Out:
# Enter the number: 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# ### 8. Create python function to check whether number is even or odd

# %%
num = float(input("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")
# Out:
# Enter a number: 12.5
# 12.5 is an odd number.

# %% [markdown]
# ### 9. **Calculate Area of a Rectangle**
#
# - Create a class named `Rectangle` with attributes `length` and `width`.
# - Add a method `calculate_area()` to calculate and return the area of the rectangle.
# - Create an object and display the area.

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

rectangle = Rectangle(length, width)
area = rectangle.calculate_area()
print(f"The area of the rectangle is: {area}")
# Out:
# Enter the length of the rectangle: 45
# Enter the width of the rectangle: 12
# The area of the rectangle is: 540.0

# %% [markdown]
# ### 10. **Data Cleaning & Analysis with Pandas**
#
# **Task:**
#
# - Create a Pandas DataFrame with student names, ages, and grades.
# - Replace missing grades with the mean grade.
# - Filter students with grades above 80.
# - Display the final cleaned DataFrame.

# %%
import pandas as pd
import numpy as np

data = {'Name': ['Shakeel', 'ALi Nazar', 'Safullah', 'Hena', 'Shakeel'],
        'Age': [20, 22, 19, 21, 20],
        'Grade': [85, 92, np.nan, 78, 88]}
df = pd.DataFrame(data)

mean_grade = df['Grade'].mean()


df['Grade'].fillna(mean_grade, inplace=True)

filtered_df = df[df['Grade'] > 80]

filtered_df
# Out:
# <ipython-input-21-c08777bd77a4>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Grade'].fillna(mean_grade, inplace=True)
#         Name  Age  Grade
# 0    Shakeel   20  85.00
# 1  ALi Nazar   22  92.00
# 2   Safullah   19  85.75
# 4    Shakeel   20  88.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# filtered_df['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# filtered_df['Grade'].plot(kind='hist', bins=20, title='Grade')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# filtered_df.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# filtered_df.plot(kind='scatter', x='Age', y='Grade', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# filtered_df['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# filtered_df['Grade'].plot(kind='line', figsize=(8, 4), title='Grade')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(filtered_df['Name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(filtered_df, x='Age', y='Name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(filtered_df['Name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(filtered_df, x='Grade', y='Name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### 11. **BMI Calculator with Classification**
# **Task:**
#
# - Ask the user for height (m) and weight (kg), calculate BMI, and classify as Underweight, Normal, Overweight, or Obese.

# %%
height = float(input("Enter your height in meters: "))
weight = float(input("Enter your weight in kilograms: "))

bmi = weight / (height ** 2)

if bmi < 18.5:
    classification = "Underweight"
elif 18.5 <= bmi < 25:
    classification = "Normal"
elif 25 <= bmi < 30:
    classification = "Overweight"
else:
    classification = "Obese"

print(f"Your BMI is: {bmi:.2f}")
print(f"Classification: {classification}")
# Out:
# Enter your height in meters: 2.1
# Enter your weight in kilograms: 55
# Your BMI is: 12.47
# Classification: Underweight

# %% [markdown]
# ### 12. Generate and Visualize a Random Dataset
# **Task:**
#
# - Generate a dataset of 100 random numbers using NumPy.
# - Plot a histogram of the numbers using Matplotlib.

# %%
import matplotlib.pyplot as plt
import numpy as np

random_numbers = np.random.rand(1,100)
plt.hist(random_numbers)
plt.xlabel("Random Numbers")
plt.ylabel("Frequency")
plt.title("Histogram of Random Numbers")
plt.show()

# %% [markdown]
# ### 13. Implement a Simple Linear Regression Model
# **Task:**
#
# - Generate a small dataset with `X` and `y` values.
# - Train a linear regression model using sklearn.
# - Predict and visualize the results.

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 5, 4, 5])

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
